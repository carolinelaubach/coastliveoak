# %%
# import necessary libraries for geospatial analysis
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import plotly.express as px

# %%
# import the data from the data file
oak = pd.read_csv('../Group Data/AllOaksinLACounty.csv')
# get a sample of the first five rows of the data file
oak.head(10)
# Out:
#        id observed_on   latitude   longitude place_town_name  \
# 0    8010  2010-08-08  34.051315 -118.828232             NaN
# 1   16226  2011-04-21  34.099908 -118.723948             NaN
# 2   49531  2012-01-29  34.037792 -118.750244             NaN
# 3   52936  2012-02-21  34.210906 -118.122473             NaN
# 4   57187  2012-03-06  34.193470 -118.175340             NaN
# 5   59510  2012-03-22  34.193066 -118.104315             NaN
# 6   91634  2012-06-15  34.060028 -118.932694             NaN
# 7   94373  2012-06-21  34.321234 -118.638375             NaN
# 8   98831  2012-07-04  34.184842 -118.095442             NaN
# 9  103070  2012-07-18  34.188598 -118.177912             NaN
#
#   place_county_name         scientific_name           common_name
# 0       Los Angeles  Quercus berberidifolia  California scrub oak
# 1       Los Angeles          Quercus lobata            valley oak
# 2       Los Angeles       Quercus agrifolia        coast live oak
# 3       Los Angeles     Quercus chrysolepis       canyon live oak
# 4       Los Angeles       Quercus agrifolia        coast live oak
# 5       Los Angeles       Quercus agrifolia        coast live oak
# 6       Los Angeles       Quercus agrifolia        coast live oak
# 7       Los Angeles          Quercus lobata            valley oak
# 8       Los Angeles       Quercus agrifolia        coast live oak
# 9       Los Angeles       Quercus agrifolia        coast live oak

# %%
# convert clo to a geo data frame
geooak = gpd.GeoDataFrame(oak, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(oak.longitude, oak.latitude))

# %%
# create a plot with an added basemap to give the plot geographic context
fig, ax = plt.subplots(figsize=(12,12))
geooak.plot(ax=ax, 
        marker='+',
        markersize=10,
        color='green')
ax.axis('off')
ax.set_title('Oak Tree Observations in LA County')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)

# %%
# find the count of all oak species observations in LA County
oak_by_species = oak.value_counts('common_name').reset_index(name='count')
oak_by_species
# Out:
#                        common_name  count
# 0                   coast live oak   5807
# 1                  canyon live oak    935
# 2                       valley oak    882
# 3             California scrub oak    840
# 4                  San Gabriel oak    424
# 5                    Engelmann oak    393
# 6                     Tucker's Oak    239
# 7                interior live oak    217
# 8                       Ewan's Oak    150
# 9             California black oak    134
# 10                      island oak    132
# 11                island scrub oak    126
# 12                        Holm oak     91
# 13             California Live Oak     78
# 14                     leather oak     67
# 15                        blue oak     38
# 16          Bush Interior Live Oak     37
# 17                        Shin Oak     36
# 18              Scrub × Valley Oak     24
# 19                            oaks     19
# 20                   MacDonald Oak     19
# 21                      Alvord Oak     15
# 22                    Howell's Oak     14
# 23         Southern Coast Live Oak     12
# 24             Nuttall's scrub oak      9
# 25                       Jolon Oak      8
# 26  Coast Live × Interior Live Oak      7
# 27                      Oracle Oak      7
# 28                    Muller's oak      5
# 29              high-latitude oaks      5
# 30                    Palmer's oak      3
# 31                      Oregon oak      3
# 32               southern live oak      3
# 33             Oregon × valley oak      1
# 34               Interior live oak      1
# 35                 huckleberry oak      1
# 36             Torrey's Hybrid Oak      1
# 37                northern red oak      1
# 38                         pin oak      1

# %%
# plot the top 8 observed species
fig = px.bar(oak_by_species.head(8),
       x='common_name',
       y='count',
       title='Oak Trees in LA County by Species',
       color='common_name',
       color_discrete_sequence=px.colors.sequential.Greens_r,
       labels={'common_name': 'Species', 'count': 'Count'})

fig.show()

# %%
# import geojson for zip codes
zipcodes = gpd.read_file('../Group Data/LA_County_ZIP_Codes.geojson')

# %%
# conduct a spatial join
oak_by_zip = gpd.sjoin(zipcodes, geooak)
oak_by_zip.head(10)
# Out:
#    OBJECTID ZIPCODE  Shape_Length    Shape_Area  \
# 3         4   90004  52471.897635  8.395697e+07
# 5         6   90006  37832.454801  5.370366e+07
# 5         6   90006  37832.454801  5.370366e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
#
#                                             geometry  index_right         id  \
# 3  POLYGON ((-118.2841 34.08349, -118.28438 34.08...         3832   45336986
# 5  POLYGON ((-118.28274 34.03964, -118.28277 34.0...          280    1370257
# 5  POLYGON ((-118.28274 34.03964, -118.28277 34.0...         3151   30893549
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         7642  172401978
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...          167     546837
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...          168     546874
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         9180  211129809
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         6452  139554812
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         9691  237724501
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         1878   15916587
#
#   observed_on   latitude   longitude place_town_name place_county_name  \
# 3  2020-05-04  34.072811 -118.315812             NaN       Los Angeles
# 5  2015-04-05  34.040585 -118.283162             NaN       Los Angeles
# 5  2019-08-13  34.051303 -118.285500             NaN       Los Angeles
# 6  2023-07-11  34.016872 -118.288793             NaN       Los Angeles
# 6  2014-02-28  34.017257 -118.288591             NaN       Los Angeles
# 6  2014-02-28  34.017341 -118.288569             NaN       Los Angeles
# 6  2024-04-28  34.017468 -118.288385             NaN       Los Angeles
# 6  2022-10-21  34.017481 -118.288384             NaN       Los Angeles
# 6  2024-08-24  34.017502 -118.288892             NaN       Los Angeles
# 6  2018-08-26  34.017621 -118.288424             NaN       Los Angeles
#
#        scientific_name     common_name
# 3    Quercus agrifolia  coast live oak
# 5    Quercus agrifolia  coast live oak
# 5       Quercus lobata      valley oak
# 6  Quercus engelmannii   Engelmann oak
# 6    Quercus agrifolia  coast live oak
# 6    Quercus agrifolia  coast live oak
# 6  Quercus engelmannii   Engelmann oak
# 6  Quercus engelmannii   Engelmann oak
# 6       Quercus lobata      valley oak
# 6  Quercus engelmannii   Engelmann oak

# %%
# count the number of oaks per zip code
oak_counts = oak_by_zip.value_counts('ZIPCODE').reset_index(name='oak_count')
oak_counts
# Out:
#     ZIPCODE  oak_count
# 0     91001        850
# 1     91105        826
# 2     91011        667
# 3     91107        593
# 4     91302        528
# ..      ...        ...
# 212   91504          1
# 213   91722          1
# 214   91607          1
# 215   91755          1
# 216   91790          1
#
# [217 rows x 2 columns]

# %%
# add the count to the zip codes
oak_by_zip = oak_by_zip.merge(oak_counts, how='left',on='ZIPCODE')
oak_by_zip.head(10)
# Out:
#    OBJECTID ZIPCODE  Shape_Length    Shape_Area  \
# 0         4   90004  52471.897635  8.395697e+07
# 1         6   90006  37832.454801  5.370366e+07
# 2         6   90006  37832.454801  5.370366e+07
# 3         7   90007  57886.269976  6.859609e+07
# 4         7   90007  57886.269976  6.859609e+07
# 5         7   90007  57886.269976  6.859609e+07
# 6         7   90007  57886.269976  6.859609e+07
# 7         7   90007  57886.269976  6.859609e+07
# 8         7   90007  57886.269976  6.859609e+07
# 9         7   90007  57886.269976  6.859609e+07
#
#                                             geometry  index_right         id  \
# 0  POLYGON ((-118.2841 34.08349, -118.28438 34.08...         3832   45336986
# 1  POLYGON ((-118.28274 34.03964, -118.28277 34.0...          280    1370257
# 2  POLYGON ((-118.28274 34.03964, -118.28277 34.0...         3151   30893549
# 3  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         7642  172401978
# 4  POLYGON ((-118.29297 34.04066, -118.29331 34.0...          167     546837
# 5  POLYGON ((-118.29297 34.04066, -118.29331 34.0...          168     546874
# 6  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         9180  211129809
# 7  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         6452  139554812
# 8  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         9691  237724501
# 9  POLYGON ((-118.29297 34.04066, -118.29331 34.0...         1878   15916587
#
#   observed_on   latitude   longitude place_town_name place_county_name  \
# 0  2020-05-04  34.072811 -118.315812             NaN       Los Angeles
# 1  2015-04-05  34.040585 -118.283162             NaN       Los Angeles
# 2  2019-08-13  34.051303 -118.285500             NaN       Los Angeles
# 3  2023-07-11  34.016872 -118.288793             NaN       Los Angeles
# 4  2014-02-28  34.017257 -118.288591             NaN       Los Angeles
# 5  2014-02-28  34.017341 -118.288569             NaN       Los Angeles
# 6  2024-04-28  34.017468 -118.288385             NaN       Los Angeles
# 7  2022-10-21  34.017481 -118.288384             NaN       Los Angeles
# 8  2024-08-24  34.017502 -118.288892             NaN       Los Angeles
# 9  2018-08-26  34.017621 -118.288424             NaN       Los Angeles
#
#        scientific_name     common_name  oak_count_x  oak_count_y  oak_count
# 0    Quercus agrifolia  coast live oak            1            1          1
# 1    Quercus agrifolia  coast live oak            2            2          2
# 2       Quercus lobata      valley oak            2            2          2
# 3  Quercus engelmannii   Engelmann oak           12           12         12
# 4    Quercus agrifolia  coast live oak           12           12         12
# 5    Quercus agrifolia  coast live oak           12           12         12
# 6  Quercus engelmannii   Engelmann oak           12           12         12
# 7  Quercus engelmannii   Engelmann oak           12           12         12
# 8       Quercus lobata      valley oak           12           12         12
# 9  Quercus engelmannii   Engelmann oak           12           12         12

# %%
# choropleth map of oaks by zipcode
fig,ax = plt.subplots(figsize=(12,12))

oak_by_zip.plot(ax=ax,column='oak_count',legend=True,cmap='summer_r')
ax.axis('off')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('oaksbyzip.jpg')

# %%
# consolidate oak species into categories
geooak['common_name'] = geooak['common_name'].astype(str)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Coast Live Oak' if 'Coast Live × Interior Live Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Coast Live Oak' if 'coast live oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Canyon Live Oak' if 'canyon live oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Valley Oak' if 'valley oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'California Scrub Oak' if 'California scrub oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'San Gabriel Oak' if 'San Gabriel oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Engelmann Oak' if 'Engelmann oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Interior Live Oak' if 'interior live oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'California black oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Bush Interior Live Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Southern Coast Live Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'southern live oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'California Live Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Interior Live Oak' if 'Interior live oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Valley Oak' if 'Scrub × Valley Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'island scrub oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'island oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if "Nuttall's scrub oak" in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'nan' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Holm oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'leather oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'blue oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Shin Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'oaks' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'MacDonald Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Alvord Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if "Howell's Oak" in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Jolon Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Oracle Oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'high-latitude oaks' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if "Muller's oak" in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'Oregon oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if "Palmer's oak" in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if "Torrey's Hybrid Oak" in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'pin oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'northern red oak' in x else x)
geooak['common_name'] = geooak['common_name'].apply(lambda x: 'Oak (Other)' if 'huckleberry oak' in x else x)

# display a list of all variables to test for efficacy
geooak['common_name'].value_counts()
# Out:
# common_name
# Coast Live Oak          5814
# Oak (Other)              965
# Canyon Live Oak          935
# Valley Oak               907
# California Scrub Oak     840
# San Gabriel Oak          424
# Engelmann Oak            393
# Tucker's Oak             239
# Interior Live Oak        218
# Ewan's Oak               150
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,12))
geooak.plot(ax=ax, 
        marker='+',
        markersize=10,
        column='common_name',
        cmap='summer',
        legend = True,     
        legend_kwds={'loc':'upper left','bbox_to_anchor':(1,.9)})
ax.axis('off')
ax.set_title('Oak Tree Observations in LA County')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('oaktrees.jpg')

# %%
# import censust tracts
census = gpd.read_file('../Group Data/tigerLine-tracts-2022.zip')
census = census.to_crs(crs='EPSG:4326')

# %%
# conduct a spatial join
oak_by_tract = gpd.sjoin(census, geooak)
oak_by_tract.head(10)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 1      06      037  138000  06037138000     1380     Census Tract 1380  G5020
# 1      06      037  138000  06037138000     1380     Census Tract 1380  G5020
#
#   FUNCSTAT    ALAND  AWATER  ...  \
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 0        S  3837562       0  ...
# 1        S  4472196       0  ...
# 1        S  4472196       0  ...
#
#                                             geometry index_right         id  \
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        9387  220570286
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        4215   66208248
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        4024   59741379
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        9229  212765740
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        7134  152569569
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        6771  145160418
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        1518   10502802
# 0  POLYGON ((-118.58119 34.14318, -118.581 34.143...        4252   67322999
# 1  POLYGON ((-118.60573 34.14585, -118.60561 34.1...        2067   16861506
# 1  POLYGON ((-118.60573 34.14585, -118.60561 34.1...        8855  201828244
#
#    observed_on   latitude   longitude  place_town_name  place_county_name  \
# 0   2024-06-04  34.133678 -118.569345              NaN        Los Angeles
# 0   2020-12-06  34.145303 -118.576203              NaN        Los Angeles
# 0   2020-09-10  34.146073 -118.567611              NaN        Los Angeles
# 0   2024-04-27  34.154035 -118.566391              NaN        Los Angeles
# 0   2023-03-27  34.154167 -118.566521              NaN        Los Angeles
# 0   2022-12-26  34.154312 -118.566241              NaN        Los Angeles
# 0   2018-03-29  34.154361 -118.566341              NaN        Los Angeles
# 0   2020-12-29  34.155428 -118.565996              NaN        Los Angeles
# 1   2018-09-23  34.155806 -118.585861              NaN        Los Angeles
# 1   2023-09-10  34.156369 -118.585953              NaN        Los Angeles
#
#           scientific_name           common_name
# 0       Quercus agrifolia        Coast Live Oak
# 0       Quercus agrifolia        Coast Live Oak
# 0       Quercus agrifolia        Coast Live Oak
# 0       Quercus agrifolia        Coast Live Oak
# 0  Quercus berberidifolia  California Scrub Oak
# 0  Quercus berberidifolia  California Scrub Oak
# 0  Quercus berberidifolia  California Scrub Oak
# 0       Quercus agrifolia        Coast Live Oak
# 1       Quercus agrifolia        Coast Live Oak
# 1          Quercus lobata            Valley Oak
#
# [10 rows x 22 columns]

# %%
# count the number of oaks per tract
oak_counts1 = oak_by_tract.value_counts('GEOID').reset_index(name='oak_count')
oak_counts1
# Out:
#            GEOID  oak_count
# 0    06037930400       1554
# 1    06037460001        484
# 2    06037460101        388
# 3    06037800335        376
# 4    06037460401        343
# ..           ...        ...
# 584  06037920340          1
# 585  06037980012          1
# 586  06037980016          1
# 587  06037102103          1
# 588  06111990100          1
#
# [589 rows x 2 columns]

# %%
# add the count to the tracts
oak_by_tract = oak_by_tract.merge(oak_counts1, how='left',on='GEOID')
oak_by_tract.head(10)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 1      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 2      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 3      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 4      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 5      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 6      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 7      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 8      06      037  138000  06037138000     1380     Census Tract 1380  G5020
# 9      06      037  138000  06037138000     1380     Census Tract 1380  G5020
#
#   FUNCSTAT    ALAND  AWATER  ...         id observed_on   latitude  \
# 0        S  3837562       0  ...  220570286  2024-06-04  34.133678
# 1        S  3837562       0  ...   66208248  2020-12-06  34.145303
# 2        S  3837562       0  ...   59741379  2020-09-10  34.146073
# 3        S  3837562       0  ...  212765740  2024-04-27  34.154035
# 4        S  3837562       0  ...  152569569  2023-03-27  34.154167
# 5        S  3837562       0  ...  145160418  2022-12-26  34.154312
# 6        S  3837562       0  ...   10502802  2018-03-29  34.154361
# 7        S  3837562       0  ...   67322999  2020-12-29  34.155428
# 8        S  4472196       0  ...   16861506  2018-09-23  34.155806
# 9        S  4472196       0  ...  201828244  2023-09-10  34.156369
#
#     longitude  place_town_name place_county_name         scientific_name  \
# 0 -118.569345              NaN       Los Angeles       Quercus agrifolia
# 1 -118.576203              NaN       Los Angeles       Quercus agrifolia
# 2 -118.567611              NaN       Los Angeles       Quercus agrifolia
# 3 -118.566391              NaN       Los Angeles       Quercus agrifolia
# 4 -118.566521              NaN       Los Angeles  Quercus berberidifolia
# 5 -118.566241              NaN       Los Angeles  Quercus berberidifolia
# 6 -118.566341              NaN       Los Angeles  Quercus berberidifolia
# 7 -118.565996              NaN       Los Angeles       Quercus agrifolia
# 8 -118.585861              NaN       Los Angeles       Quercus agrifolia
# 9 -118.585953              NaN       Los Angeles          Quercus lobata
#
#             common_name oak_count_x oak_count_y
# 0        Coast Live Oak           8           8
# 1        Coast Live Oak           8           8
# 2        Coast Live Oak           8           8
# 3        Coast Live Oak           8           8
# 4  California Scrub Oak           8           8
# 5  California Scrub Oak           8           8
# 6  California Scrub Oak           8           8
# 7        Coast Live Oak           8           8
# 8        Coast Live Oak           2           2
# 9            Valley Oak           2           2
#
# [10 rows x 24 columns]

# %%
# choropleth map of oaks by tracts
fig,ax = plt.subplots(figsize=(12,12))

oak_by_tract.plot(ax=ax,column='oak_count_x',legend=True,cmap='summer_r')
ax.axis('off')
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs=4326)
plt.savefig('oaksbytract.jpg')

# %%
# plot the top 8 observed species
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Coast Live Oak' if 'Coast Live × Interior Live Oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Coast Live Oak' if 'coast live oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Canyon Live Oak' if 'canyon live oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Valley Oak' if 'valley oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'California Scrub Oak' if 'California scrub oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'San Gabriel Oak' if 'San Gabriel oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Engelmann Oak' if 'Engelmann oak' in x else x)
oak_by_species['common_name'] = oak_by_species['common_name'].apply(lambda x: 'Interior Live Oak' if 'interior live oak' in x else x)
fig = px.bar(oak_by_species.head(8),
       x='common_name',
       y='count',
       title='Oak Trees in LA County by Species',
       color='common_name',
       color_discrete_sequence=px.colors.sequential.Greens_r,
       labels={'common_name': 'Species', 'count': 'Count'})

fig.show()
